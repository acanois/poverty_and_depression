# %%
import pandas as pd

# %%
df = pd.read_csv('BRFSS_2014_Overall.csv')

# %%
df.columns
# Out:
# Index(['Year', 'Locationabbr', 'Locationdesc', 'Class', 'Topic', 'Question',
#        'Response', 'Break_Out', 'Break_Out_Category', 'Sample_Size',
#        'Data_value', 'Confidence_limit_Low', 'Confidence_limit_High',
#        'Display_order', 'Data_value_unit', 'Data_value_type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'DataSource',
#        'ClassId', 'TopicId', 'LocationID', 'BreakoutID', 'BreakOutCategoryID',
#        'QuestionID', 'ResponseID', 'GeoLocation'],
#       dtype='object')

# %%
df.QuestionID.unique().tolist()
# Out:
# ['RACE',
#  'SEX',
#  'DRNKANY5',
#  '_RFBING5',
#  '_RFDRHV4',
#  '_DRDXAR1',
#  '_CASTHM1',
#  '_LTASTH1',
#  'CVDCRHD4',
#  'CVDINFR4',
#  'CVDSTRK3',
#  'CHCCOPD1',
#  'ADDEPEV2',
#  'DIABETE3',
#  'CHCKIDNY',
#  'CHCOCNCR',
#  'CHCSCNCR',
#  '_RFBLDS2',
#  '_RFBLDS3',
#  '_RFSIGM2',
#  '_CRCREC',
#  'AGE',
#  'BLIND',
#  'DECIDE',
#  'DIFFALON',
#  'DIFFDRES',
#  'DIFFWALK',
#  'QLACTLM2',
#  'USEEQUIP',
#  'EDUCA',
#  'EMPLOY1',
#  'INCOME',
#  'INTERNET',
#  'MARITAL',
#  '_CHLDCNT',
#  'RENTHOM1',
#  'VETERAN3',
#  'MEDCOST',
#  'HLTHPLN1',
#  'CHECKUP1',
#  'PERSDOC2',
#  '_HCVU651',
#  '_RFHLTH',
#  'GENHLTH',
#  'HIVTST6',
#  '_FLSHOT6',
#  '_PNEUMO2',
#  'SHINGLE2',
#  '_DRNKDRV',
#  '_RFSEAT3',
#  '_ALTETH2',
#  '_DENVST2',
#  '_EXTETH2',
#  '_BMI5CAT',
#  '_TOTINDA',
#  '_RFPSA21',
#  '_RFSMOK3',
#  'USENOW3',
#  '_SMOKER3',
#  '_MAM5021',
#  '_MAM502Y',
#  '_RFMAM2Y',
#  '_RFPAP32',
#  '_RFPAP33']

# %%
dep_df = df.loc[df.QuestionID == 'ADDEPEV2']

# %%
dep_df = dep_df.loc[df.Response == 'Yes']

# %%
dep_df
# Out:
#       Year Locationabbr                                Locationdesc  \
# 25    2014           AL                                     Alabama
# 196   2014           AK                                      Alaska
# 366   2014           AZ                                     Arizona
# 531   2014           AR                                    Arkansas
# 704   2014           CA                                  California
# 870   2014           CO                                    Colorado
# 1041  2014           CT                                 Connecticut
# 1212  2014           DE                                    Delaware
# 1377  2014           DC                        District of Columbia
# 1546  2014           FL                                     Florida
# 1712  2014           GA                                     Georgia
# 1879  2014           HI                                      Hawaii
# 2050  2014           ID                                       Idaho
# ...

# %%
dep_df.to_csv('depression_dataset.csv')

# %%
dep_df.drop(8977)
dep_df.drop(9146)
# Out:
#       Year Locationabbr                   Locationdesc  \
# 25    2014           AL                        Alabama
# 196   2014           AK                         Alaska
# 366   2014           AZ                        Arizona
# 531   2014           AR                       Arkansas
# 704   2014           CA                     California
# 870   2014           CO                       Colorado
# 1041  2014           CT                    Connecticut
# 1212  2014           DE                       Delaware
# 1377  2014           DC           District of Columbia
# 1546  2014           FL                        Florida
# 1712  2014           GA                        Georgia
# 1879  2014           HI                         Hawaii
# 2050  2014           ID                          Idaho
# 2220  2014           IL                       Illinois
# 2388  2014           IN                        Indiana
# 2557  2014           IA                           Iowa
# ...
